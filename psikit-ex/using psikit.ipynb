# %% [markdown]
# Single point calculation

# %%
from psikit import Psikit
pk = Psikit()
pk.read_from_smiles("c1ccccc1")
print("SCF Energy: ", pk.energy())
print("HOMO: ", pk.HOMO)
print("LUMO: ", pk.LUMO)
x, y, z, total = pk.dipolemoment
print("SCF Total Dipole Moment: {}".format(total))
# SCF Energy:  -230.712279648862
# HOMO:  -0.32848562009092513
# LUMO:  0.1456515222506689
# SCF Total Dipole Moment: 3.292464934070545e-05
# Out:
# SCF Energy:  -230.71227965254417
# HOMO:  -0.3284852027451567
# LUMO:  0.1456522094409086
# SCF Total Dipole Moment: 3.297919925869793e-05

# %% [markdown]
# Structure Optimization

# %%
pk = Psikit()
pk.read_from_smiles("c1ccccc1")
print("Optimized SCF Energy: ", pk.optimize())
# Optimizer: Optimization complete!
# Optimized SCF Energy:  -230.71352354223438
# Out:
# Optimizer: Optimization complete!
# Optimized SCF Energy:  -230.71352354176997

# %% [markdown]
# Calculate RESP charge

# %%
# REF http://ambermd.org/tutorials/advanced/tutorial1/files/resp_paper_jacs.pdf
pk = Psikit()
pk.read_from_smiles("CC(=O)O")
pk.optimize()
# Optimizer: Optimization complete!
# -227.82180859253418
pk.calc_resp_charges()
# array([-0.32506898,  0.83672649, -0.61924915, -0.66135715,  0.10450057,
#    0.10478188,  0.10780051,  0.45186584])

for atom in pk.mol.GetAtoms(): 
    print(atom.GetSymbol(), "ESP:{}\tRESP:{}".format(atom.GetProp("EP"), atom.GetProp("RESP"))) 

# C ESP:-0.49662019588648315	RESP:-0.3250689814483399
# C ESP:0.91473263536048643		RESP:0.83672648554100837
# O ESP:-0.63823808477114718	RESP:-0.61924915363703359
# O ESP:-0.6763331997116846		RESP:-0.66135714989354499
# H ESP:0.14625849864628995		RESP:0.10450056830656008
# H ESP:0.14578513969681847		RESP:0.10478187811883517
# H ESP:0.1530843954112609		RESP:0.1078005104750676
# H ESP:0.45133081125445906		RESP:0.45186584253744722

### Compute Mulliken charges and Lowdin charges

pk = Psikit()
pk.read_from_smiles("CC(=O)O")
pk.optimize() # or pk.energy()

pk.calc_mulliken_charges()
# array([-0.42203029,  0.72794785, -0.55419051, -0.59333358,  0.16369722,
#    0.1636994 ,  0.15462075,  0.35958916])

pk.calc_lowdin_charges()
#array([-0.30006577,  0.33900448, -0.35983788, -0.28463832,  0.12439944,
#    0.12810672,  0.11935266,  0.23367866])
# Out:
# Optimizer: Optimization complete!
# please install resp at first
# conda install -c psi4 resp
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-b14b93731b67> in <module>
#      10
#      11 for atom in pk.mol.GetAtoms():
# ---> 12     print(atom.GetSymbol(), "ESP:{}\tRESP:{}".format(atom.GetProp("EP"), atom.GetProp("RESP")))
#      13
#      14 # C ESP:-0.49662019588648315    RESP:-0.3250689814483399
#
# KeyError: 'EP'

# %%
from psikit import Psikit
pk = Psikit()
pk.read_from_smiles("c1ccccc1")
pk.optimize(basis_sets="scf/sto-3g")
pk.view_on_pymol() # launch pymol as a RPC server in advance, just type "pymol -R"
# Out:
# Optimizer: Optimization complete!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-2ebdb44c380e> in <module>
#       3 pk.read_from_smiles("c1ccccc1")
#       4 pk.optimize(basis_sets="scf/sto-3g")
# ----> 5 pk.view_on_pymol() # launch pymol as a RPC server in advance, just type "pymol -R"
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/psikit/psikit.py in view_on_pymol(self, target, maprange, gridspace)
#     127     def view_on_pymol(self, target='FRONTIER', maprange=0.05, gridspace=0.3):
#     128         self.create_cube_files(gridspace=gridspace)
# --> 129         run_pymol_server(self.tempdir, target=target, maprange=maprange)
#     130
#     131     def save_frontier(self, gridspace=0.3, isotype="isosurface"):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/psikit/pymol_helper.py in run_pymol_server(tmpdir, target, maprange)
#      14     import xmlrpc.client as xmlrpc
#      15     srv = xmlrpc.ServerProxy('http://localhost:9123')
# ---> 16     srv.do('delete *')
#      17     srv.do('load '+os.path.join(tmpdir, 'target.mol'))
#      18     srv.do('as sticks, target')
#
# /srv/conda/envs/notebook/lib/python3.7/xmlrpc/client.py in __call__(self, *args)
#    1110         return _Method(self.__send, "%s.%s" % (self.__name, name))
#    1111     def __call__(self, *args):
# -> 1112         return self.__send(self.__name, args)
#    1113
#    1114 ##
#
# /srv/conda/envs/notebook/lib/python3.7/xmlrpc/client.py in __request(self, methodname, params)
#    1450             self.__handler,
#    1451             request,
# -> 1452             verbose=self.__verbose
#    1453             )
#    1454
#
# /srv/conda/envs/notebook/lib/python3.7/xmlrpc/client.py in request(self, host, handler, request_body, verbose)
#    1152         for i in (0, 1):
#    1153             try:
# -> 1154                 return self.single_request(host, handler, request_body, verbose)
#    1155             except http.client.RemoteDisconnected:
#    1156                 if i:
#
# /srv/conda/envs/notebook/lib/python3.7/xmlrpc/client.py in single_request(self, host, handler, request_body, verbose)
#    1164         # issue XML-RPC request
#    1165         try:
# -> 1166             http_conn = self.send_request(host, handler, request_body, verbose)
#    1167             resp = http_conn.getresponse()
#    1168             if resp.status == 200:
#
# /srv/conda/envs/notebook/lib/python3.7/xmlrpc/client.py in send_request(self, host, handler, request_body, debug)
#    1277         headers.append(("User-Agent", self.user_agent))
#    1278         self.send_headers(connection, headers)
# -> 1279         self.send_content(connection, request_body)
#    1280         return connection
#    1281
#
# /srv/conda/envs/notebook/lib/python3.7/xmlrpc/client.py in send_content(self, connection, request_body)
#    1307
#    1308         connection.putheader("Content-Length", str(len(request_body)))
# -> 1309         connection.endheaders(request_body)
#    1310
#    1311     ##
#
# /srv/conda/envs/notebook/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1270         else:
#    1271             raise CannotSendHeader()
# -> 1272         self._send_output(message_body, encode_chunked=encode_chunked)
#    1273
#    1274     def request(self, method, url, body=None, headers={}, *,
#
# /srv/conda/envs/notebook/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1030         msg = b"\r\n".join(self._buffer)
#    1031         del self._buffer[:]
# -> 1032         self.send(msg)
#    1033
#    1034         if message_body is not None:
#
# /srv/conda/envs/notebook/lib/python3.7/http/client.py in send(self, data)
#     970         if self.sock is None:
#     971             if self.auto_open:
# --> 972                 self.connect()
#     973             else:
#     974                 raise NotConnected()
#
# /srv/conda/envs/notebook/lib/python3.7/http/client.py in connect(self)
#     942         """Connect to the host and port specified in __init__."""
#     943         self.sock = self._create_connection(
# --> 944             (self.host,self.port), self.timeout, self.source_address)
#     945         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     946
#
# /srv/conda/envs/notebook/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
#     727         try:
# --> 728             raise err
#     729         finally:
#     730             # Break explicitly a reference cycle
#
# /srv/conda/envs/notebook/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# OSError: [Errno 99] Cannot assign requested address
